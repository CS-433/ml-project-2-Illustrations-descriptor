# %% [markdown]
# ## Setup
# This is originally on Google Colab.

# %%
from google.colab import drive
drive.mount("/content/drive")

# Direct to your assignment folder.
# %cd /content/drive/MyDrive/ML_P2_Illustrations

# %load_ext autoreload
# %autoreload 1

# Install
# !pip install torch torchvision torchaudio ultralytics supervision
# !!pip install transformers accelerate sentencepiece
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ML_P2_Illustrations
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Collecting ultralytics
#   Downloading ultralytics-8.3.48-py3-none-any.whl.metadata (35 kB)
# Collecting supervision
#   Downloading supervision-0.25.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from supervision) (1.3.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from supervision) (0.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Downloading ultralytics-8.3.48-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 23.9 MB/s eta 0:00:00
# Downloading supervision-0.25.0-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 17.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, supervision, ultralytics
# Successfully installed supervision-0.25.0 ultralytics-8.3.48 ultralytics-thop-2.0.13
# ['Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)',
#  'Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.1.1)',
#  'Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)',
#  'Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)',
#  'Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.3)',
#  'Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)',
#  'Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)',
#  'Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)',
#  'Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)',
#  'Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)',
#  'Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)',
#  'Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)',
#  'Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)',
#  'Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)',
#  'Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)',
#  'Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)',
#  'Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)',
#  'Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)',
#  'Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)',
#  'Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)',
#  'Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)',
#  'Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)',
#  'Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)',
#  'Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)',
#  'Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)',
#  'Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)']

# %% [markdown]
# ## Entity Detection & Image Captioning
# We applied YOLOv10 for entity detection and BLIP for image captioning to the whole dataset. For entity detection, the confidence threshold is set as 5% again for flexible future filtering.

# %%
import os
import json
import torch
from ultralytics import YOLO
import supervision as sv
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# Settings
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
CONFIDENCE_THRESHOLD = 0.05

# Load YOLO model
yolo_model = YOLO("yolov10x.pt")

# Load BLIP model
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to(DEVICE)

# Define category mappings
category_dict = {
    0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus',
    6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant',
    11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat',
    16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear',
    22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie',
    28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball',
    33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard',
    37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass',
    41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana',
    47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot',
    52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair',
    57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet',
    62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard',
    67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink',
    72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors',
    77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'
}

animal_classes = {'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe'}

# Classification logic
def classify_detections(detected_classes):
    has_human = 'person' in detected_classes
    has_animal = any(animal in detected_classes for animal in animal_classes)
    if has_human and has_animal:
        return "Both"
    elif has_human:
        return "Human"
    elif has_animal:
        return "Animal"
    else:
        return "Neither"

# Process images with YOLO
def process_with_yolo(image_path):
    results = yolo_model(image_path, conf=CONFIDENCE_THRESHOLD, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)

    detected_entities = []
    detected_classes = []

    for class_id, confidence, bbox in zip(detections.class_id, detections.confidence, detections.xyxy):
        class_name = category_dict[class_id]
        detected_classes.append(class_name)
        detected_entities.append({
            "class": class_name,
            "confidence": float(confidence),  # Convert to float for JSON serialization
            "bounding_box": [float(coord) for coord in bbox]  # Convert to list of floats
        })

    classification = classify_detections(detected_classes)
    return classification, detected_entities

# Process images with BLIP for caption generation
def process_with_blip(image_path):
    try:
        # Load and preprocess the image
        image = Image.open(image_path).convert("RGB")
        inputs = blip_processor(images=image, return_tensors="pt").to(DEVICE)
        outputs = blip_model.generate(**inputs, max_new_tokens=50)
        caption = blip_processor.decode(outputs[0], skip_special_tokens=True)
        return caption
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
        return "Error"

# Process the whole dataset and save as JSON
def process_dataset(base_folder):
    for folder_name in os.listdir(base_folder):
        folder_path = os.path.join(base_folder, folder_name)
        if not os.path.isdir(folder_path):
            continue

        # Initialize results for the folder
        folder_results = {
            "book_name": folder_name,
            "pages": []
        }

        for file_name in os.listdir(folder_path):
            if file_name.endswith(".png"):
                image_path = os.path.join(folder_path, file_name)

                # YOLO detections
                classification, detected_entities = process_with_yolo(image_path)

                # BLIP caption
                caption = process_with_blip(image_path)

                # Append detection result
                folder_results["pages"].append({
                    "page": file_name,
                    "classification": classification,
                    "detected_entities": detected_entities,
                    "caption": caption
                })

        # Save results as JSON
        output_file_path = os.path.join(folder_path, f"detections.json")
        with open(output_file_path, 'w') as json_file:
            json.dump(folder_results, json_file, indent=4)

        print(f"Processed folder: {folder_name}, results saved to {output_file_path}")

# Define base folder for dataset
base_folder = "preprocessed_all"

# Run dataset processing
process_dataset(base_folder)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Processed folder: lifedeathofjenny00newyiala, results saved to preprocessed_all/lifedeathofjenny00newyiala/detections.json
# Processed folder: lifedeathofjenny00yorkiala, results saved to preprocessed_all/lifedeathofjenny00yorkiala/detections.json
# Processed folder: lifeingreenwood00lans, results saved to preprocessed_all/lifeingreenwood00lans/detections.json
# Processed folder: lifeofgeorgewash00ceciiala, results saved to preprocessed_all/lifeofgeorgewash00ceciiala/detections.json
# Processed folder: lifeofjacksprath00londiala, results saved to preprocessed_all/lifeofjacksprath00londiala/detections.json
# Processed folder: lifeofjacksprath00manciala, results saved to preprocessed_all/lifeofjacksprath00manciala/detections.json
# Processed folder: lifeofjacksprath00yorkiala, results saved to preprocessed_all/lifeofjacksprath00yorkiala/detections.json
# Processed folder: lifeofjosephson00macgiala, results saved to preprocessed_all/lifeofjosephson00macgiala/detections.json
# Processed folder: lifetravelsvoyag00watsiala, results saved to preprocessed_all/lifetravelsvoyag00watsiala/detections.json
# Processed folder: lightforlittleon00wateiala, results saved to preprocessed_all/lightforlittleon00wateiala/detections.json
# Processed folder: lightheartedgirl00aldeiala, results saved to preprocessed_all/lightheartedgirl00aldeiala/detections.json
# Processed folder: lightkeepersstor00otis, results saved to preprocessed_all/lightkeepersstor00otis/detections.json
# Processed folder: lilliputianlibra01gulliala, results saved to preprocessed_all/lilliputianlibra01gulliala/detections.json
# Processed folder: lilliputianlibra02gulliala, results saved to preprocessed_all/lilliputianlibra02gulliala/detections.json
# Processed folder: lilliputianmagaz00londiala, results saved to preprocessed_all/lilliputianmagaz00londiala/detections.json
# Processed folder: lilysscrapbook00barkiala, results saved to preprocessed_all/lilysscrapbook00barkiala/detections.json
# Processed folder: linette00labe, results saved to preprocessed_all/linette00labe/detections.json
# Processed folder: linnetslifetwelv00tayliala, results saved to preprocessed_all/linnetslifetwelv00tayliala/detections.json
# Processed folder: lionbenofelmisla00kell, results saved to preprocessed_all/lionbenofelmisla00kell/detections.json
# Processed folder: lionotherstories00newyiala, results saved to preprocessed_all/lionotherstories00newyiala/detections.json
# Processed folder: lionsmasquerades00dorsiala, results saved to preprocessed_all/lionsmasquerades00dorsiala/detections.json
# Processed folder: littlealfred00kiddiala, results saved to preprocessed_all/littlealfred00kiddiala/detections.json
# Processed folder: littlealfredorin00williala, results saved to preprocessed_all/littlealfredorin00williala/detections.json
# Processed folder: littleannandothe00tayliala, results saved to preprocessed_all/littleannandothe00tayliala/detections.json
# Processed folder: littleannorfamil00reliiala, results saved to preprocessed_all/littleannorfamil00reliiala/detections.json
# Processed folder: littleapostleonc00dela, results saved to preprocessed_all/littleapostleonc00dela/detections.json
# Processed folder: littleblossomsre00john, results saved to preprocessed_all/littleblossomsre00john/detections.json
# Processed folder: littleblueeyesot00londiala, results saved to preprocessed_all/littleblueeyesot00londiala/detections.json
# Processed folder: littlebopeep00londiala, results saved to preprocessed_all/littlebopeep00londiala/detections.json
# Processed folder: littleboysplayfe00philiala, results saved to preprocessed_all/littleboysplayfe00philiala/detections.json
# Processed folder: littleboystreasu00addi, results saved to preprocessed_all/littleboystreasu00addi/detections.json
# Processed folder: littlebutaffecti00sanbiala, results saved to preprocessed_all/littlebutaffecti00sanbiala/detections.json
# Processed folder: littleclown00cobbiala, results saved to preprocessed_all/littleclown00cobbiala/detections.json
# Processed folder: littlecolonel00john, results saved to preprocessed_all/littlecolonel00john/detections.json
# Processed folder: littlecroppythem00hughiala, results saved to preprocessed_all/littlecroppythem00hughiala/detections.json
# Processed folder: littlecurlylocks00cinciala, results saved to preprocessed_all/littlecurlylocks00cinciala/detections.json
# Processed folder: littledamecrumph00londiala, results saved to preprocessed_all/littledamecrumph00londiala/detections.json
# Processed folder: littlederwentsbr00treviala, results saved to preprocessed_all/littlederwentsbr00treviala/detections.json
# Processed folder: littleditties00newyiala, results saved to preprocessed_all/littleditties00newyiala/detections.json
# Processed folder: littledoctorvict00carniala, results saved to preprocessed_all/littledoctorvict00carniala/detections.json
# Processed folder: littledownyorhis00traiiala, results saved to preprocessed_all/littledownyorhis00traiiala/detections.json
# Processed folder: littledukerichar00yong3, results saved to preprocessed_all/littledukerichar00yong3/detections.json
# Processed folder: littleellieother00andeiala, results saved to preprocessed_all/littleellieother00andeiala/detections.json
# Processed folder: littleemmaherfa00horwiala, results saved to preprocessed_all/littleemmaherfa00horwiala/detections.json
# Processed folder: littleemmaherfat00horwiala, results saved to preprocessed_all/littleemmaherfat00horwiala/detections.json
# Processed folder: littleenglishgir00belfiala, results saved to preprocessed_all/littleenglishgir00belfiala/detections.json
# Processed folder: littlefernsforfa00ferniala, results saved to preprocessed_all/littlefernsforfa00ferniala/detections.json
# Processed folder: littlefolksastra00mays, results saved to preprocessed_all/littlefolksastra00mays/detections.json
# Processed folder: littlefolksastra00maysiala, results saved to preprocessed_all/littlefolksastra00maysiala/detections.json
# Processed folder: littlefolksinbus00harr, results saved to preprocessed_all/littlefolksinbus00harr/detections.json
# Processed folder: littlefolksownst00good, results saved to preprocessed_all/littlefolksownst00good/detections.json
# Processed folder: littlefolkspaint00weatiala, results saved to preprocessed_all/littlefolkspaint00weatiala/detections.json
# Processed folder: littlefollowerof00grus, results saved to preprocessed_all/littlefollowerof00grus/detections.json
# Processed folder: littleforgetmeno00newhiala, results saved to preprocessed_all/littleforgetmeno00newhiala/detections.json
# Processed folder: littlefrankieath00lesliala, results saved to preprocessed_all/littlefrankieath00lesliala/detections.json
# Processed folder: littlefrankieats00lesliala, results saved to preprocessed_all/littlefrankieats00lesliala/detections.json
# Processed folder: littlefrankiehis00lesliala, results saved to preprocessed_all/littlefrankiehis00lesliala/detections.json
# Processed folder: littlefrankieonj00lesliala, results saved to preprocessed_all/littlefrankieonj00lesliala/detections.json
# Processed folder: littlefrankother00londiala, results saved to preprocessed_all/littlefrankother00londiala/detections.json
# Processed folder: littlegirlinoldn00doug, results saved to preprocessed_all/littlegirlinoldn00doug/detections.json
# Processed folder: littlegirllostta00rapeiala, results saved to preprocessed_all/littlegirllostta00rapeiala/detections.json
# Processed folder: littlegirlshouse00mitfiala, results saved to preprocessed_all/littlegirlshouse00mitfiala/detections.json
# Processed folder: littlegirltoherf00londiala, results saved to preprocessed_all/littlegirltoherf00londiala/detections.json
# Processed folder: littlegirlwhowas00bostiala, results saved to preprocessed_all/littlegirlwhowas00bostiala/detections.json
# Processed folder: littlegoodytwo00goldiala, results saved to preprocessed_all/littlegoodytwo00goldiala/detections.json
# Processed folder: littlegoodytwosh00goldiala, results saved to preprocessed_all/littlegoodytwosh00goldiala/detections.json
# Processed folder: littlegrainsforl00coxpiala, results saved to preprocessed_all/littlegrainsforl00coxpiala/detections.json
# Processed folder: littlegrandfathe00mays, results saved to preprocessed_all/littlegrandfathe00mays/detections.json
# Processed folder: littlehannahleew00wilsiala, results saved to preprocessed_all/littlehannahleew00wilsiala/detections.json
# Processed folder: littlehelpers00janv, results saved to preprocessed_all/littlehelpers00janv/detections.json
# Processed folder: littlehenryhisbi00daniiala, results saved to preprocessed_all/littlehenryhisbi00daniiala/detections.json
# Processed folder: littlehermitaget00jaufiala, results saved to preprocessed_all/littlehermitaget00jaufiala/detections.json
# Processed folder: littlehunchbackf00londiala, results saved to preprocessed_all/littlehunchbackf00londiala/detections.json
# Processed folder: littleislanderso00londiala, results saved to preprocessed_all/littleislanderso00londiala/detections.json
# Processed folder: littlejackfoundl00daytiala, results saved to preprocessed_all/littlejackfoundl00daytiala/detections.json
# Processed folder: littlejimcrowoth00morr, results saved to preprocessed_all/littlejimcrowoth00morr/detections.json
# Processed folder: littlekeepsake00feltiala, results saved to preprocessed_all/littlekeepsake00feltiala/detections.json
# Processed folder: littlelamelordor00elms, results saved to preprocessed_all/littlelamelordor00elms/detections.json
# Processed folder: littlelessonsfor00newhiala, results saved to preprocessed_all/littlelessonsfor00newhiala/detections.json
# Processed folder: littlelordfauntl00burn4, results saved to preprocessed_all/littlelordfauntl00burn4/detections.json
# Processed folder: littlelordfauntl00burniala, results saved to preprocessed_all/littlelordfauntl00burniala/detections.json
# Processed folder: littlelouvreorbo00abboiala, results saved to preprocessed_all/littlelouvreorbo00abboiala/detections.json
# Processed folder: littlelucyorplea00newhiala, results saved to preprocessed_all/littlelucyorplea00newhiala/detections.json
# Processed folder: littlemaidofmass00curt, results saved to preprocessed_all/littlemaidofmass00curt/detections.json
# Processed folder: littlemaryorpict00ceciiala, results saved to preprocessed_all/littlemaryorpict00ceciiala/detections.json
# Processed folder: littlemaryortalk00trusiala, results saved to preprocessed_all/littlemaryortalk00trusiala/detections.json
# Processed folder: littlematchman00barz, results saved to preprocessed_all/littlematchman00barz/detections.json
# Processed folder: littlemenlifeatp00alcoiala, results saved to preprocessed_all/littlemenlifeatp00alcoiala/detections.json
# Processed folder: littlemilldamwit00bostiala, results saved to preprocessed_all/littlemilldamwit00bostiala/detections.json
# Processed folder: littlemrthimblef00harr2, results saved to preprocessed_all/littlemrthimblef00harr2/detections.json
# Processed folder: littlenancyorpun00philiala, results saved to preprocessed_all/littlenancyorpun00philiala/detections.json
# Processed folder: littlenightcaple00fanniala, results saved to preprocessed_all/littlenightcaple00fanniala/detections.json
# Processed folder: littleosagecapti00corniala, results saved to preprocessed_all/littleosagecapti00corniala/detections.json
# Processed folder: littlepaul00milliala, results saved to preprocessed_all/littlepaul00milliala/detections.json
# Processed folder: littlepeoplealph00crosiala, results saved to preprocessed_all/littlepeoplealph00crosiala/detections.json
# Processed folder: littleplayfellow00cinciala, results saved to preprocessed_all/littleplayfellow00cinciala/detections.json
# Processed folder: littleplaymates00cinciala, results saved to preprocessed_all/littleplaymates00cinciala/detections.json
# Processed folder: littlepresent00greeiala, results saved to preprocessed_all/littlepresent00greeiala/detections.json
# Processed folder: littlepresentfor00greeiala, results saved to preprocessed_all/littlepresentfor00greeiala/detections.json
# Processed folder: littleprimerbook00pittiala, results saved to preprocessed_all/littleprimerbook00pittiala/detections.json
# Processed folder: littleprudy00clar3, results saved to preprocessed_all/littleprudy00clar3/detections.json
# Processed folder: littleprudy00maysiala, results saved to preprocessed_all/littleprudy00maysiala/detections.json
# Processed folder: littleprudymayso00maysiala, results saved to preprocessed_all/littleprudymayso00maysiala/detections.json
# Processed folder: littleprudyscapt00clar2, results saved to preprocessed_all/littleprudyscapt00clar2/detections.json
# Processed folder: littleprudyscapt00maysiala, results saved to preprocessed_all/littleprudyscapt00maysiala/detections.json
# Processed folder: littleprudyssist00mays, results saved to preprocessed_all/littleprudyssist00mays/detections.json
# Processed folder: littlequakerortr00moodiala, results saved to preprocessed_all/littlequakerortr00moodiala/detections.json
# Processed folder: littlequeenofhea00ogde, results saved to preprocessed_all/littlequeenofhea00ogde/detections.json
# Processed folder: littleramblersot00newy, results saved to preprocessed_all/littleramblersot00newy/detections.json
# Processed folder: littleredridingh00summiala, results saved to preprocessed_all/littleredridingh00summiala/detections.json
# Processed folder: littlerobertowl00sheriala, results saved to preprocessed_all/littlerobertowl00sheriala/detections.json
# Processed folder: littlerobinslove00lesliala, results saved to preprocessed_all/littlerobinslove00lesliala/detections.json
# Processed folder: littlerosysvoyag00hetz, results saved to preprocessed_all/littlerosysvoyag00hetz/detections.json
# Processed folder: littlerubiwoodca00newyiala, results saved to preprocessed_all/littlerubiwoodca00newyiala/detections.json
# Processed folder: littlesaintsunsh00goss, results saved to preprocessed_all/littlesaintsunsh00goss/detections.json
# Processed folder: littlesallyofsab00conciala, results saved to preprocessed_all/littlesallyofsab00conciala/detections.json
# Processed folder: littlescenesforl00londiala, results saved to preprocessed_all/littlescenesforl00londiala/detections.json
# Processed folder: littlesistersore00sbabiala, results saved to preprocessed_all/littlesistersore00sbabiala/detections.json
# Processed folder: littlesketchbook00lanciala, results saved to preprocessed_all/littlesketchbook00lanciala/detections.json
# Processed folder: littlesongs00foll, results saved to preprocessed_all/littlesongs00foll/detections.json
# Processed folder: littlesophytrues00derbiala, results saved to preprocessed_all/littlesophytrues00derbiala/detections.json
# Processed folder: littlestoriesofo00londiala, results saved to preprocessed_all/littlestoriesofo00londiala/detections.json
# Processed folder: littlestoryforli00greeiala, results saved to preprocessed_all/littlestoryforli00greeiala/detections.json
# Processed folder: littlestorytelle00glasiala, results saved to preprocessed_all/littlestorytelle00glasiala/detections.json
# Processed folder: littlesusanherla00ameriala, results saved to preprocessed_all/littlesusanherla00ameriala/detections.json
# Processed folder: littletimhisfrie00londiala, results saved to preprocessed_all/littletimhisfrie00londiala/detections.json
# Processed folder: littletom00till, results saved to preprocessed_all/littletom00till/detections.json
# Processed folder: littletommyssled00cinciala, results saved to preprocessed_all/littletommyssled00cinciala/detections.json
# Processed folder: littletomtelltru00reliiala, results saved to preprocessed_all/littletomtelltru00reliiala/detections.json
# Processed folder: littletomtucker00yorkiala, results saved to preprocessed_all/littletomtucker00yorkiala/detections.json
# Processed folder: littleversesforg00ameriala, results saved to preprocessed_all/littleversesforg00ameriala/detections.json
# Processed folder: littleversesforg00greeiala, results saved to preprocessed_all/littleversesforg00greeiala/detections.json
# Processed folder: littlevisitorsin00hackiala, results saved to preprocessed_all/littlevisitorsin00hackiala/detections.json
# Processed folder: littlewandererso00johniala, results saved to preprocessed_all/littlewandererso00johniala/detections.json
# Processed folder: littlewarblerofc00loveiala, results saved to preprocessed_all/littlewarblerofc00loveiala/detections.json
# Processed folder: littlewheelbarro00bostiala, results saved to preprocessed_all/littlewheelbarro00bostiala/detections.json
# Processed folder: littlewhitebarba00marciala, results saved to preprocessed_all/littlewhitebarba00marciala/detections.json
# Processed folder: littlewomanpedla00londiala, results saved to preprocessed_all/littlewomanpedla00londiala/detections.json
# Processed folder: littlewomanthepe00mulriala, results saved to preprocessed_all/littlewomanthepe00mulriala/detections.json
# Processed folder: littlewomenormeg00alcoiala, results saved to preprocessed_all/littlewomenormeg00alcoiala/detections.json
# Processed folder: littleyellowwang00belliala, results saved to preprocessed_all/littleyellowwang00belliala/detections.json
# Processed folder: livedollorellens00authiala, results saved to preprocessed_all/livedollorellens00authiala/detections.json
# Processed folder: loganmingostoryo00elli, results saved to preprocessed_all/loganmingostoryo00elli/detections.json
# Processed folder: londonscenesorvi00londiala, results saved to preprocessed_all/londonscenesorvi00londiala/detections.json
# Processed folder: longjohn00cinciala, results saved to preprocessed_all/longjohn00cinciala/detections.json
# Processed folder: lookingglassorne00gainiala, results saved to preprocessed_all/lookingglassorne00gainiala/detections.json
# Processed folder: lossrecoveryothe00troyiala, results saved to preprocessed_all/lossrecoveryothe00troyiala/detections.json
# Processed folder: lostchildpoetict00williala, results saved to preprocessed_all/lostchildpoetict00williala/detections.json
# Processed folder: lostinrockiessto00elli, results saved to preprocessed_all/lostinrockiessto00elli/detections.json
# Processed folder: lostkeyfry00frysiala, results saved to preprocessed_all/lostkeyfry00frysiala/detections.json
# Processed folder: lostlambothertal00aldeiala, results saved to preprocessed_all/lostlambothertal00aldeiala/detections.json
# Processed folder: lostlegendsofnur00clariala, results saved to preprocessed_all/lostlegendsofnur00clariala/detections.json
# Processed folder: lostlenoreoradve00reid, results saved to preprocessed_all/lostlenoreoradve00reid/detections.json
# Processed folder: lottiegraceortwo00londiala, results saved to preprocessed_all/lottiegraceortwo00londiala/detections.json
# Processed folder: louisaorvirtuous00dubliala, results saved to preprocessed_all/louisaorvirtuous00dubliala/detections.json
# Processed folder: louisduvaltaleof00whymiala, results saved to preprocessed_all/louisduvaltaleof00whymiala/detections.json
# Processed folder: lovesweetenstrut00reliiala, results saved to preprocessed_all/lovesweetenstrut00reliiala/detections.json
# Processed folder: lucillaorreconci01sandiala, results saved to preprocessed_all/lucillaorreconci01sandiala/detections.json
# Processed folder: lucillaorreconci02sandiala, results saved to preprocessed_all/lucillaorreconci02sandiala/detections.json
# Processed folder: lucylittleenquir00londiala, results saved to preprocessed_all/lucylittleenquir00londiala/detections.json
# Processed folder: lucyorlittleenqu00londiala, results saved to preprocessed_all/lucyorlittleenqu00londiala/detections.json
# Processed folder: lucytheirmajesti00farj, results saved to preprocessed_all/lucytheirmajesti00farj/detections.json
# Processed folder: ludfordboxachris00alde, results saved to preprocessed_all/ludfordboxachris00alde/detections.json
# Processed folder: lullabycollectio00yorkiala, results saved to preprocessed_all/lullabycollectio00yorkiala/detections.json
# Processed folder: lullabywithorigi00feltiala, results saved to preprocessed_all/lullabywithorigi00feltiala/detections.json
# Processed folder: lulualphabet00colmiala, results saved to preprocessed_all/lulualphabet00colmiala/detections.json
# Processed folder: madelainetubeher00londiala, results saved to preprocessed_all/madelainetubeher00londiala/detections.json
# Processed folder: madpranksoftomtr00crouiala, results saved to preprocessed_all/madpranksoftomtr00crouiala/detections.json
# Processed folder: magicalnoteitsco00londiala, results saved to preprocessed_all/magicalnoteitsco00londiala/detections.json
# Processed folder: magicringotheror00bobbiala, results saved to preprocessed_all/magicringotheror00bobbiala/detections.json
# Processed folder: magicwordstalefo00maceiala, results saved to preprocessed_all/magicwordstalefo00maceiala/detections.json
# Processed folder: magnetstoriesfor00frisiala, results saved to preprocessed_all/magnetstoriesfor00frisiala/detections.json
# Processed folder: maidmagpieoranne00caigiala, results saved to preprocessed_all/maidmagpieoranne00caigiala/detections.json
# Processed folder: maidthemagpieint00moreiala, results saved to preprocessed_all/maidthemagpieint00moreiala/detections.json
# Processed folder: mammasdarling00bostiala, results saved to preprocessed_all/mammasdarling00bostiala/detections.json
# Processed folder: mammastalesorple00leiniala, results saved to preprocessed_all/mammastalesorple00leiniala/detections.json
# Processed folder: mammasversesorli00breniala, results saved to preprocessed_all/mammasversesorli00breniala/detections.json
# Processed folder: marchen00bech, results saved to preprocessed_all/marchen00bech/detections.json
# Processed folder: marcopaulsvoyage00abboiala, results saved to preprocessed_all/marcopaulsvoyage00abboiala/detections.json
# Processed folder: marcyrefugee00cast, results saved to preprocessed_all/marcyrefugee00cast/detections.json
# Processed folder: margaretarmstron00gull, results saved to preprocessed_all/margaretarmstron00gull/detections.json
# Processed folder: marigoldgardenpi00gree, results saved to preprocessed_all/marigoldgardenpi00gree/detections.json
# Processed folder: marjoriedeancollsen00lest, results saved to preprocessed_all/marjoriedeancollsen00lest/detections.json
# Processed folder: markssadventures00londiala, results saved to preprocessed_all/markssadventures00londiala/detections.json
# Processed folder: marksshistoryofa00londiala, results saved to preprocessed_all/marksshistoryofa00londiala/detections.json
# Processed folder: marktiddeditor00kell, results saved to preprocessed_all/marktiddeditor00kell/detections.json
# Processed folder: marktiddhisadven00kell, results saved to preprocessed_all/marktiddhisadven00kell/detections.json
# Processed folder: marktiddmanufact00kell, results saved to preprocessed_all/marktiddmanufact00kell/detections.json
# Processed folder: marshallsedition00londiala, results saved to preprocessed_all/marshallsedition00londiala/detections.json
# Processed folder: marthashookseyes00newyiala, results saved to preprocessed_all/marthashookseyes00newyiala/detections.json
# Processed folder: martinjamesorrew00leejiala, results saved to preprocessed_all/martinjamesorrew00leejiala/detections.json
# Processed folder: martinrattlerorb00ball, results saved to preprocessed_all/martinrattlerorb00ball/detections.json
# Processed folder: marvelouslandofo00baum, results saved to preprocessed_all/marvelouslandofo00baum/detections.json
# Processed folder: maryburnsorbeset00bake, results saved to preprocessed_all/maryburnsorbeset00bake/detections.json
# Processed folder: marycharlieoreve00sociiala, results saved to preprocessed_all/marycharlieoreve00sociiala/detections.json
# Processed folder: marygraytaleforl00knigiala, results saved to preprocessed_all/marygraytaleforl00knigiala/detections.json
# Processed folder: maryholmesorprid00good, results saved to preprocessed_all/maryholmesorprid00good/detections.json
# Processed folder: maryjanehervisit00juds, results saved to preprocessed_all/maryjanehervisit00juds/detections.json
# Processed folder: maryjaneinneweng00juds, results saved to preprocessed_all/maryjaneinneweng00juds/detections.json
# Processed folder: maryjonesotherbo00ameriala, results saved to preprocessed_all/maryjonesotherbo00ameriala/detections.json
# Processed folder: marysbookofhymns00conciala, results saved to preprocessed_all/marysbookofhymns00conciala/detections.json
# Processed folder: marywareintexas00john, results saved to preprocessed_all/marywareintexas00john/detections.json
# Processed folder: marywarelittleco00john, results saved to preprocessed_all/marywarelittleco00john/detections.json
# Processed folder: marywarespromise00john, results saved to preprocessed_all/marywarespromise00john/detections.json
# Processed folder: masterskylarkorw00burr, results saved to preprocessed_all/masterskylarkorw00burr/detections.json
# Processed folder: matildaoradventu00londiala, results saved to preprocessed_all/matildaoradventu00londiala/detections.json
# Processed folder: matsuyamamirror00jameiala, results saved to preprocessed_all/matsuyamamirror00jameiala/detections.json
# Processed folder: maudsummerssight00absoiala, results saved to preprocessed_all/maudsummerssight00absoiala/detections.json
# Processed folder: mauriceguildford00reliiala, results saved to preprocessed_all/mauriceguildford00reliiala/detections.json
# Processed folder: maximsmoralsfrom00franiala, results saved to preprocessed_all/maximsmoralsfrom00franiala/detections.json
# Processed folder: maydayanecdotesl00londiala, results saved to preprocessed_all/maydayanecdotesl00londiala/detections.json
# Processed folder: maydayanecdoteso00londiala, results saved to preprocessed_all/maydayanecdoteso00londiala/detections.json
# Processed folder: maydayoranecdote00londiala, results saved to preprocessed_all/maydayoranecdote00londiala/detections.json
# Processed folder: mayorgrandpapasp00gris, results saved to preprocessed_all/mayorgrandpapasp00gris/detections.json
# Processed folder: maysadvicetochil00ameriala, results saved to preprocessed_all/maysadvicetochil00ameriala/detections.json
# Processed folder: mcguffeyseclecti00mcgu, results saved to preprocessed_all/mcguffeyseclecti00mcgu/detections.json
# Processed folder: mcguffeysseconde00mcgu, results saved to preprocessed_all/mcguffeysseconde00mcgu/detections.json
# Processed folder: medleymedley00newyiala, results saved to preprocessed_all/medleymedley00newyiala/detections.json
# Processed folder: medleymedley00portiala, results saved to preprocessed_all/medleymedley00portiala/detections.json
# Processed folder: medleyorstoriesf00hamiiala, results saved to preprocessed_all/medleyorstoriesf00hamiiala/detections.json
# Processed folder: medleysamuelwood00newyiala, results saved to preprocessed_all/medleysamuelwood00newyiala/detections.json
# Processed folder: meggieofthepines00bakeiala, results saved to preprocessed_all/meggieofthepines00bakeiala/detections.json
# Processed folder: megothers00coms, results saved to preprocessed_all/megothers00coms/detections.json
# Processed folder: melchiorsdreambr00ewin, results saved to preprocessed_all/melchiorsdreambr00ewin/detections.json
# Processed folder: melchiorsdreamot00ewin4, results saved to preprocessed_all/melchiorsdreamot00ewin4/detections.json
# Processed folder: melchiorsdreamot00ewiniala, results saved to preprocessed_all/melchiorsdreamot00ewiniala/detections.json
# Processed folder: memoirofmiriamwa00newyiala, results saved to preprocessed_all/memoirofmiriamwa00newyiala/detections.json
# Processed folder: memoirsofdicklit00londiala, results saved to preprocessed_all/memoirsofdicklit00londiala/detections.json
# Processed folder: memoirsofdickyye00greyiala, results saved to preprocessed_all/memoirsofdickyye00greyiala/detections.json
# Processed folder: memoirsofemmaher00cameiala, results saved to preprocessed_all/memoirsofemmaher00cameiala/detections.json
# Processed folder: memoirsoflittlem00londiala, results saved to preprocessed_all/memoirsoflittlem00londiala/detections.json
# Processed folder: memoirsofsargean00amer, results saved to preprocessed_all/memoirsofsargean00amer/detections.json
# Processed folder: memoirsofsilviop00pelliala, results saved to preprocessed_all/memoirsofsilviop00pelliala/detections.json
# Processed folder: mentalimprovemen00wakeiala, results saved to preprocessed_all/mentalimprovemen00wakeiala/detections.json
# Processed folder: mermanfigurehead00guer, results saved to preprocessed_all/mermanfigurehead00guer/detections.json
# Processed folder: merryandreworhum00welliala, results saved to preprocessed_all/merryandreworhum00welliala/detections.json
# Processed folder: merryandrewwhich00breniala, results saved to preprocessed_all/merryandrewwhich00breniala/detections.json
# Processed folder: merryclappumjunc00kenniala, results saved to preprocessed_all/merryclappumjunc00kenniala/detections.json
# Processed folder: merrywordsformer00hoatiala, results saved to preprocessed_all/merrywordsformer00hoatiala/detections.json
# Processed folder: metamorphosesor00hughiala, results saved to preprocessed_all/metamorphosesor00hughiala/detections.json
# Processed folder: metamorphosesore00hughiala, results saved to preprocessed_all/metamorphosesore00hughiala/detections.json
# Processed folder: metricalhistoryo00halliala, results saved to preprocessed_all/metricalhistoryo00halliala/detections.json
# Processed folder: mildredsinherita00john, results saved to preprocessed_all/mildredsinherita00john/detections.json
# Processed folder: millerhisgolden00leoniala, results saved to preprocessed_all/millerhisgolden00leoniala/detections.json
# Processed folder: millerhisgoldend00leoniala, results saved to preprocessed_all/millerhisgoldend00leoniala/detections.json
# Processed folder: milliedlothrop00bostiala, results saved to preprocessed_all/milliedlothrop00bostiala/detections.json
# Processed folder: millthatcharlesb00londiala, results saved to preprocessed_all/millthatcharlesb00londiala/detections.json
# Processed folder: miniatureunderwi00greeiala, results saved to preprocessed_all/miniatureunderwi00greeiala/detections.json
# Processed folder: ministeringchild00char, results saved to preprocessed_all/ministeringchild00char/detections.json
# Processed folder: minniebrownorgen00wiseiala, results saved to preprocessed_all/minniebrownorgen00wiseiala/detections.json
# Processed folder: minniegrayormeri00philiala, results saved to preprocessed_all/minniegrayormeri00philiala/detections.json
# Processed folder: minnieorlittlewo00guiliala, results saved to preprocessed_all/minnieorlittlewo00guiliala/detections.json
# Processed folder: minniespetdogill00lesliala, results saved to preprocessed_all/minniespetdogill00lesliala/detections.json
# Processed folder: minniespetlambil00lesliala, results saved to preprocessed_all/minniespetlambil00lesliala/detections.json
# Processed folder: minniespetmonkey00lesliala, results saved to preprocessed_all/minniespetmonkey00lesliala/detections.json
# Processed folder: minniespetparrot00lesliala, results saved to preprocessed_all/minniespetparrot00lesliala/detections.json
# Processed folder: minuteboysofbost00otis, results saved to preprocessed_all/minuteboysofbost00otis/detections.json
# Processed folder: minuteboysofyork00otis, results saved to preprocessed_all/minuteboysofyork00otis/detections.json
# Processed folder: miquettebaptises00camo, results saved to preprocessed_all/miquettebaptises00camo/detections.json
# Processed folder: miscellaniesmora00jameiala, results saved to preprocessed_all/miscellaniesmora00jameiala/detections.json
# Processed folder: mismelissasbaby00free, results saved to preprocessed_all/mismelissasbaby00free/detections.json
# Processed folder: missherdollornew00londiala, results saved to preprocessed_all/missherdollornew00londiala/detections.json
# Processed folder: missingpocketboo00cast, results saved to preprocessed_all/missingpocketboo00cast/detections.json
# Processed folder: missingprince00farriala, results saved to preprocessed_all/missingprince00farriala/detections.json
# Processed folder: misspatsgreatide00gint, results saved to preprocessed_all/misspatsgreatide00gint/detections.json
# Processed folder: missrose00londiala, results saved to preprocessed_all/missrose00londiala/detections.json
# Processed folder: misterfox00newyiala, results saved to preprocessed_all/misterfox00newyiala/detections.json
# Processed folder: modernarabiadisp00londiala, results saved to preprocessed_all/modernarabiadisp00londiala/detections.json
# Processed folder: molly00yech, results saved to preprocessed_all/molly00yech/detections.json
# Processed folder: monkeysfrolic00londiala, results saved to preprocessed_all/monkeysfrolic00londiala/detections.json
# Processed folder: monkeysfrolichum00londiala, results saved to preprocessed_all/monkeysfrolichum00londiala/detections.json
# Processed folder: moovisi, results saved to preprocessed_all/moovisi/detections.json
# Processed folder: moralentertainin00londiala, results saved to preprocessed_all/moralentertainin00londiala/detections.json
# Processed folder: moralentertainin00uxbriala, results saved to preprocessed_all/moralentertainin00uxbriala/detections.json
# Processed folder: moralistoramusin00londiala, results saved to preprocessed_all/moralistoramusin00londiala/detections.json
# Processed folder: moralscenesinrus00londiala, results saved to preprocessed_all/moralscenesinrus00londiala/detections.json
# Processed folder: moralsketchesfor00johniala, results saved to preprocessed_all/moralsketchesfor00johniala/detections.json
# Processed folder: moraltales00londiala, results saved to preprocessed_all/moraltales00londiala/detections.json
# Processed folder: moraltalesinpros00londiala, results saved to preprocessed_all/moraltalesinpros00londiala/detections.json
# Processed folder: moraltalesinvers00londiala, results saved to preprocessed_all/moraltalesinvers00londiala/detections.json
# Processed folder: moredollies00cobbiala, results saved to preprocessed_all/moredollies00cobbiala/detections.json
# Processed folder: moreminormoralso00londiala, results saved to preprocessed_all/moreminormoralso00londiala/detections.json
# Processed folder: moremittenswithd00fann, results saved to preprocessed_all/moremittenswithd00fann/detections.json
# Processed folder: moreshortstorie00sempiala, results saved to preprocessed_all/moreshortstorie00sempiala/detections.json
# Processed folder: moretalesforidle00londiala, results saved to preprocessed_all/moretalesforidle00londiala/detections.json
# Processed folder: moretalesfromara00lane, results saved to preprocessed_all/moretalesfromara00lane/detections.json
# Processed folder: morningfaces00hunt, results saved to preprocessed_all/morningfaces00hunt/detections.json
# Processed folder: morningramble00feltiala, results saved to preprocessed_all/morningramble00feltiala/detections.json
# Processed folder: morningrambleeng00feltiala, results saved to preprocessed_all/morningrambleeng00feltiala/detections.json
# Processed folder: morningrambleori00feltiala, results saved to preprocessed_all/morningrambleori00feltiala/detections.json
# Processed folder: morningrambleorm00andeiala, results saved to preprocessed_all/morningrambleorm00andeiala/detections.json
# Processed folder: morningramblewit00feltiala, results saved to preprocessed_all/morningramblewit00feltiala/detections.json
# Processed folder: mosaiccreationor00londiala, results saved to preprocessed_all/mosaiccreationor00londiala/detections.json
# Processed folder: motherearthschil00gord, results saved to preprocessed_all/motherearthschil00gord/detections.json
# Processed folder: mothergooseinhie00philiala, results saved to preprocessed_all/mothergooseinhie00philiala/detections.json
# Processed folder: mothergooseinwhi00goodiala, results saved to preprocessed_all/mothergooseinwhi00goodiala/detections.json
# Processed folder: mothergooseorold00greeiala, results saved to preprocessed_all/mothergooseorold00greeiala/detections.json
# Processed folder: mothergooseschim00philiala, results saved to preprocessed_all/mothergooseschim00philiala/detections.json
# Processed folder: mothergoosesmelo00boweiala, results saved to preprocessed_all/mothergoosesmelo00boweiala/detections.json
# Processed folder: mothergoosesmelo00newyiala, results saved to preprocessed_all/mothergoosesmelo00newyiala/detections.json
# Processed folder: mothergoosesnurs00craniala, results saved to preprocessed_all/mothergoosesnurs00craniala/detections.json
# Processed folder: motherhubbard00martiala, results saved to preprocessed_all/motherhubbard00martiala/detections.json
# Processed folder: motherhubbardsdo00martiala, results saved to preprocessed_all/motherhubbardsdo00martiala/detections.json
# Processed folder: motherlesselleno00bostiala, results saved to preprocessed_all/motherlesselleno00bostiala/detections.json
# Processed folder: mothermugginherd00londiala, results saved to preprocessed_all/mothermugginherd00londiala/detections.json
# Processed folder: motherscarerewar00hughiala, results saved to preprocessed_all/motherscarerewar00hughiala/detections.json
# Processed folder: mothersfablesin00aveliala, results saved to preprocessed_all/mothersfablesin00aveliala/detections.json
# Processed folder: mothersfablesinv00aveliala, results saved to preprocessed_all/mothersfablesinv00aveliala/detections.json
# Processed folder: mothersgift00yorkiala, results saved to preprocessed_all/mothersgift00yorkiala/detections.json
# Processed folder: mothersgiftorpre00halliala, results saved to preprocessed_all/mothersgiftorpre00halliala/detections.json
# Processed folder: mothersnosegay00cameiala, results saved to preprocessed_all/mothersnosegay00cameiala/detections.json
# Processed folder: motherspresentho00colm, results saved to preprocessed_all/motherspresentho00colm/detections.json
# Processed folder: motherwestwindwh00burg, results saved to preprocessed_all/motherwestwindwh00burg/detections.json
# Processed folder: motherwestwindwhy00burg, results saved to preprocessed_all/motherwestwindwhy00burg/detections.json
# Processed folder: motorboatclubatn00hanc, results saved to preprocessed_all/motorboatclubatn00hanc/detections.json
# Processed folder: motorcardumpyboo00crosiala, results saved to preprocessed_all/motorcardumpyboo00crosiala/detections.json
# Processed folder: mountainhealthor00cameiala, results saved to preprocessed_all/mountainhealthor00cameiala/detections.json
# Processed folder: mountainluteorha00berqiala, results saved to preprocessed_all/mountainluteorha00berqiala/detections.json
# Processed folder: mountainofhealth00cameiala, results saved to preprocessed_all/mountainofhealth00cameiala/detections.json
# Processed folder: mouseswedding00londiala, results saved to preprocessed_all/mouseswedding00londiala/detections.json
# Processed folder: movingpicturegir00hope, results saved to preprocessed_all/movingpicturegir00hope/detections.json
# Processed folder: mrpunchtuck00londiala, results saved to preprocessed_all/mrpunchtuck00londiala/detections.json
# Processed folder: mrrabbitathomese00harr2, results saved to preprocessed_all/mrrabbitathomese00harr2/detections.json
# Processed folder: mrrutherfordschi00warniala, results saved to preprocessed_all/mrrutherfordschi00warniala/detections.json
# Processed folder: mrsprimhersonjim00bostiala, results saved to preprocessed_all/mrsprimhersonjim00bostiala/detections.json
# Processed folder: mrsturnerscautio00turniala, results saved to preprocessed_all/mrsturnerscautio00turniala/detections.json
# Processed folder: mungolittletrave00mistiala, results saved to preprocessed_all/mungolittletrave00mistiala/detections.json
# Processed folder: mungoorthelittle00mistiala, results saved to preprocessed_all/mungoorthelittle00mistiala/detections.json
# Processed folder: museedepoup00pari, results saved to preprocessed_all/museedepoup00pari/detections.json
# Processed folder: myauntlucysgifte00baltiala, results saved to preprocessed_all/myauntlucysgifte00baltiala/detections.json
# Processed folder: mybirdmydogtalef00mineiala, results saved to preprocessed_all/mybirdmydogtalef00mineiala/detections.json
# Processed folder: myfirstalphabet00londiala, results saved to preprocessed_all/myfirstalphabet00londiala/detections.json
# Processed folder: myfrienddoggie00glasiala, results saved to preprocessed_all/myfrienddoggie00glasiala/detections.json
# Processed folder: myfriendjimstory00doyl, results saved to preprocessed_all/myfriendjimstory00doyl/detections.json
# Processed folder: myfriendorincide00londiala, results saved to preprocessed_all/myfriendorincide00londiala/detections.json
# Processed folder: mygoverness00uptoiala, results saved to preprocessed_all/mygoverness00uptoiala/detections.json
# Processed folder: mygrandfatheroff00londiala, results saved to preprocessed_all/mygrandfatheroff00londiala/detections.json
# Processed folder: mylordbagorice00chamiala, results saved to preprocessed_all/mylordbagorice00chamiala/detections.json
# Processed folder: myoddlittlefolkr00doug, results saved to preprocessed_all/myoddlittlefolkr00doug/detections.json
# Processed folder: myowntreasurygif00londiala, results saved to preprocessed_all/myowntreasurygif00londiala/detections.json
# Processed folder: mypicturebook00bobbiala, results saved to preprocessed_all/mypicturebook00bobbiala/detections.json
# Processed folder: myprettypresent00newyiala, results saved to preprocessed_all/myprettypresent00newyiala/detections.json
# Processed folder: myprettyscrapboo00cuppiala, results saved to preprocessed_all/myprettyscrapboo00cuppiala/detections.json
# Processed folder: myrealfriendorin00londiala, results saved to preprocessed_all/myrealfriendorin00londiala/detections.json
# Processed folder: mysteryofsealark00barb, results saved to preprocessed_all/mysteryofsealark00barb/detections.json
# Processed folder: mystrangefriend00finn, results saved to preprocessed_all/mystrangefriend00finn/detections.json
# Processed folder: mythslegendsofpa00juds, results saved to preprocessed_all/mythslegendsofpa00juds/detections.json
# Processed folder: nancylee00dunt, results saved to preprocessed_all/nancylee00dunt/detections.json
# Processed folder: nancyleesspringt00dunt, results saved to preprocessed_all/nancyleesspringt00dunt/detections.json
# Processed folder: nationalnurseryb00londiala, results saved to preprocessed_all/nationalnurseryb00londiala/detections.json
# Processed folder: naturalhistoryof00coluiala, results saved to preprocessed_all/naturalhistoryof00coluiala/detections.json
# Processed folder: naturedisplayedd00martiala, results saved to preprocessed_all/naturedisplayedd00martiala/detections.json
# Processed folder: naturemythsstori00cookiala, results saved to preprocessed_all/naturemythsstori00cookiala/detections.json
# Processed folder: naughtypuppies00newyiala, results saved to preprocessed_all/naughtypuppies00newyiala/detections.json
# Processed folder: nautilus00richiala, results saved to preprocessed_all/nautilus00richiala/detections.json
# Processed folder: nealmillersonofl00otis, results saved to preprocessed_all/nealmillersonofl00otis/detections.json
# Processed folder: necklaceofprince00demoiala, results saved to preprocessed_all/necklaceofprince00demoiala/detections.json
# Processed folder: nedgrahamotherst00bostiala, results saved to preprocessed_all/nedgrahamotherst00bostiala/detections.json
# Processed folder: nedinblockhouset00elli, results saved to preprocessed_all/nedinblockhouset00elli/detections.json
# Processed folder: nedwildingsdisap00chap, results saved to preprocessed_all/nedwildingsdisap00chap/detections.json
# Processed folder: nellysfirstschoo00fran, results saved to preprocessed_all/nellysfirstschoo00fran/detections.json
# Processed folder: nesfive, results saved to preprocessed_all/nesfive/detections.json
# Processed folder: neuesdeutsc00bech, results saved to preprocessed_all/neuesdeutsc00bech/detections.json
# Processed folder: newcriesoflondon00bishiala, results saved to preprocessed_all/newcriesoflondon00bishiala/detections.json
# Processed folder: newenglandpsalte00kneeiala, results saved to preprocessed_all/newenglandpsalte00kneeiala/detections.json
# Processed folder: newhistoryofblue00blueiala, results saved to preprocessed_all/newhistoryofblue00blueiala/detections.json
# Processed folder: newhistoryofblue00gaffiala, results saved to preprocessed_all/newhistoryofblue00gaffiala/detections.json
# Processed folder: newhistoryofgrec00johniala, results saved to preprocessed_all/newhistoryofgrec00johniala/detections.json
# Processed folder: newjuvenilescrap00ceciiala, results saved to preprocessed_all/newjuvenilescrap00ceciiala/detections.json
# Processed folder: newsacreddramasf00dubriala, results saved to preprocessed_all/newsacreddramasf00dubriala/detections.json
# Processed folder: newslan, results saved to preprocessed_all/newslan/detections.json
# Processed folder: newtomthumbwith00mackiala, results saved to preprocessed_all/newtomthumbwith00mackiala/detections.json
# Processed folder: newtomthumbwitha00mackiala, results saved to preprocessed_all/newtomthumbwitha00mackiala/detections.json
# Processed folder: newyearsgiftcont00gainiala, results saved to preprocessed_all/newyearsgiftcont00gainiala/detections.json
# Processed folder: newyearsgiftforl00glasiala, results saved to preprocessed_all/newyearsgiftforl00glasiala/detections.json
# Processed folder: nicsqua, results saved to preprocessed_all/nicsqua/detections.json
# Processed folder: nightsofroundtab00john, results saved to preprocessed_all/nightsofroundtab00john/detections.json
# Processed folder: ninelivesofcatta00benniala, results saved to preprocessed_all/ninelivesofcatta00benniala/detections.json
# Processed folder: ninepennypieceth00proviala, results saved to preprocessed_all/ninepennypieceth00proviala/detections.json
# Processed folder: ninette00pari, results saved to preprocessed_all/ninette00pari/detections.json
# Processed folder: nobleprancingcan00londiala, results saved to preprocessed_all/nobleprancingcan00londiala/detections.json
# Processed folder: norsestoriesreto00mabi, results saved to preprocessed_all/norsestoriesreto00mabi/detections.json
# Processed folder: nosectinheaven00cleaiala, results saved to preprocessed_all/nosectinheaven00cleaiala/detections.json
# Processed folder: nosenfantsscenes00fran, results saved to preprocessed_all/nosenfantsscenes00fran/detections.json
# Processed folder: nospetitsalsacie00kauf, results saved to preprocessed_all/nospetitsalsacie00kauf/detections.json
# Processed folder: nothingventureno00haveiala, results saved to preprocessed_all/nothingventureno00haveiala/detections.json
# Processed folder: nouveauvoyageenf00unpa, results saved to preprocessed_all/nouveauvoyageenf00unpa/detections.json
# Processed folder: nouvelleshistoir00frai, results saved to preprocessed_all/nouvelleshistoir00frai/detections.json
# Processed folder: nsspllr, results saved to preprocessed_all/nsspllr/detections.json
# Processed folder: nuovaornewbeesto00kell, results saved to preprocessed_all/nuovaornewbeesto00kell/detections.json
# Processed folder: nurnbergstove00ouid, results saved to preprocessed_all/nurnbergstove00ouid/detections.json
# Processed folder: nursedandlems00dandiala, results saved to preprocessed_all/nursedandlems00dandiala/detections.json
# ...
# Processed folder: joelboyofgalilee00john, results saved to preprocessed_all/joelboyofgalilee00john/detections.json
# Processed folder: johnashtonoremig00sociiala, results saved to preprocessed_all/johnashtonoremig00sociiala/detections.json
# Processed folder: johnburroughsboy00barr, results saved to preprocessed_all/johnburroughsboy00barr/detections.json
# Processed folder: johngilpinssteam00cowpiala, results saved to preprocessed_all/johngilpinssteam00cowpiala/detections.json
# Processed folder: johnjuilushenry00londiala, results saved to preprocessed_all/johnjuilushenry00londiala/detections.json
# Processed folder: johnnotsowrongaf00londiala, results saved to preprocessed_all/johnnotsowrongaf00londiala/detections.json
# Processed folder: johnshawbillings00garr2, results saved to preprocessed_all/johnshawbillings00garr2/detections.json
# Processed folder: jollybookofboxcr00bear, results saved to preprocessed_all/jollybookofboxcr00bear/detections.json
# Processed folder: jollymillerswife00clariala, results saved to preprocessed_all/jollymillerswife00clariala/detections.json
# Processed folder: jonasjudgeorlawa00abboiala, results saved to preprocessed_all/jonasjudgeorlawa00abboiala/detections.json
# Processed folder: jonasonfarminwin00abboiala, results saved to preprocessed_all/jonasonfarminwin00abboiala/detections.json
# Processed folder: jonassstoriesrel00abboiala, results saved to preprocessed_all/jonassstoriesrel00abboiala/detections.json
# Processed folder: josephineoradvan00fordiala, results saved to preprocessed_all/josephineoradvan00fordiala/detections.json
# Processed folder: josiahinnewyorko00otis, results saved to preprocessed_all/josiahinnewyorko00otis/detections.json
# Processed folder: journalsjournali00meyn, results saved to preprocessed_all/journalsjournali00meyn/detections.json
# Processed folder: joyeuseshistoire00hoff, results saved to preprocessed_all/joyeuseshistoire00hoff/detections.json
# Processed folder: juliacaryherkitt00milliala, results saved to preprocessed_all/juliacaryherkitt00milliala/detections.json
# Processed folder: juliafannytwofri00horwiala, results saved to preprocessed_all/juliafannytwofri00horwiala/detections.json
# Processed folder: juliasundayschoo00philiala, results saved to preprocessed_all/juliasundayschoo00philiala/detections.json
# Processed folder: juniorcoed00leea, results saved to preprocessed_all/juniorcoed00leea/detections.json
# Processed folder: juvenilealmanack00londiala, results saved to preprocessed_all/juvenilealmanack00londiala/detections.json
# Processed folder: juvenileannualor00maxwiala, results saved to preprocessed_all/juvenileannualor00maxwiala/detections.json
# Processed folder: juvenileartist00bartiala, results saved to preprocessed_all/juvenileartist00bartiala/detections.json
# Processed folder: juvenilecasket00worciala, results saved to preprocessed_all/juvenilecasket00worciala/detections.json
# Processed folder: juvenilecorrespo00loveiala, results saved to preprocessed_all/juvenilecorrespo00loveiala/detections.json
# Processed folder: juvenileforgetme00bachiala, results saved to preprocessed_all/juvenileforgetme00bachiala/detections.json
# Processed folder: juvenilegardener00ladyiala, results saved to preprocessed_all/juvenilegardener00ladyiala/detections.json
# Processed folder: juvenileguideins00londiala, results saved to preprocessed_all/juvenileguideins00londiala/detections.json
# Processed folder: juvenileincident00ediniala, results saved to preprocessed_all/juvenileincident00ediniala/detections.json
# Processed folder: juvenilelessonso00smitiala, results saved to preprocessed_all/juvenilelessonso00smitiala/detections.json
# Processed folder: juvenilemirrorco00londiala, results saved to preprocessed_all/juvenilemirrorco00londiala/detections.json
# Processed folder: juvenileolioorme00mavoiala, results saved to preprocessed_all/juvenileolioorme00mavoiala/detections.json
# Processed folder: juvenilephilosop00corbiala, results saved to preprocessed_all/juvenilephilosop00corbiala/detections.json
# Processed folder: juvenilepoems00wendiala, results saved to preprocessed_all/juvenilepoems00wendiala/detections.json
# Processed folder: juvenilescrapboo00bouiiala, results saved to preprocessed_all/juvenilescrapboo00bouiiala/detections.json
# Processed folder: juvenilespect00arguiala, results saved to preprocessed_all/juvenilespect00arguiala/detections.json
# Processed folder: juvenilespectato00arguiala, results saved to preprocessed_all/juvenilespectato00arguiala/detections.json
# Processed folder: juvenilesportsor00londiala, results saved to preprocessed_all/juvenilesportsor00londiala/detections.json
# Processed folder: juvenilestoryboo00coleiala, results saved to preprocessed_all/juvenilestoryboo00coleiala/detections.json
# Processed folder: juveniletalesfor00rileiala, results saved to preprocessed_all/juveniletalesfor00rileiala/detections.json
# Processed folder: juveniletalestoe00londiala, results saved to preprocessed_all/juveniletalestoe00londiala/detections.json
# Processed folder: juveniletrials00johniala, results saved to preprocessed_all/juveniletrials00johniala/detections.json
# Processed folder: karlkrinkenhisch00warniala, results saved to preprocessed_all/karlkrinkenhisch00warniala/detections.json
# Processed folder: kateysvoyage00whymiala, results saved to preprocessed_all/kateysvoyage00whymiala/detections.json
# Processed folder: kathiesauntruth00doug, results saved to preprocessed_all/kathiesauntruth00doug/detections.json
# Processed folder: kathiesthreewish00doug, results saved to preprocessed_all/kathiesthreewish00doug/detections.json
# Processed folder: katrinastory00gils, results saved to preprocessed_all/katrinastory00gils/detections.json
# Processed folder: keeperstravelsin00kend, results saved to preprocessed_all/keeperstravelsin00kend/detections.json
# Processed folder: keepingtrysttale00john, results saved to preprocessed_all/keepingtrysttale00john/detections.json
# Processed folder: keepsakeorpoems00londiala, results saved to preprocessed_all/keepsakeorpoems00londiala/detections.json
# Processed folder: keepsakeorpoemsp00londiala, results saved to preprocessed_all/keepsakeorpoemsp00londiala/detections.json
# Processed folder: keepsakepictureb00londiala, results saved to preprocessed_all/keepsakepictureb00londiala/detections.json
# Processed folder: keytobetsysheart00ives, results saved to preprocessed_all/keytobetsysheart00ives/detections.json
# Processed folder: kinderund00grim, results saved to preprocessed_all/kinderund00grim/detections.json
# Processed folder: kinderund00grim3, results saved to preprocessed_all/kinderund00grim3/detections.json
# Processed folder: kinderundgesamme00grim, results saved to preprocessed_all/kinderundgesamme00grim/detections.json
# Processed folder: kinggobblesfeast00howaiala, results saved to preprocessed_all/kinggobblesfeast00howaiala/detections.json
# Processed folder: kingofgeewhiz00houg, results saved to preprocessed_all/kingofgeewhiz00houg/detections.json
# Processed folder: kingthebondmen00whymiala, results saved to preprocessed_all/kingthebondmen00whymiala/detections.json
# Processed folder: kingtimeormystic00fitz, results saved to preprocessed_all/kingtimeormystic00fitz/detections.json
# Processed folder: kitofgreenacrefa00forr, results saved to preprocessed_all/kitofgreenacrefa00forr/detections.json
# Processed folder: kittenscatsbooko00grov, results saved to preprocessed_all/kittenscatsbooko00grov/detections.json
# Processed folder: kittymaynardorto00guer, results saved to preprocessed_all/kittymaynardorto00guer/detections.json
# Processed folder: kittysclassday00alcoiala, results saved to preprocessed_all/kittysclassday00alcoiala/detections.json
# Processed folder: knifegrindersbud00londiala, results saved to preprocessed_all/knifegrindersbud00londiala/detections.json
# Processed folder: kobboltozosequel00cran, results saved to preprocessed_all/kobboltozosequel00cran/detections.json
# Processed folder: kutnarsonofpic00lang, results saved to preprocessed_all/kutnarsonofpic00lang/detections.json
# Processed folder: labbeconstatin001834, results saved to preprocessed_all/labbeconstatin001834/detections.json
# Processed folder: labelleauboisdor00perr, results saved to preprocessed_all/labelleauboisdor00perr/detections.json
# Processed folder: laboulayesfairyb00labo, results saved to preprocessed_all/laboulayesfairyb00labo/detections.json
# Processed folder: lacivilite001836, results saved to preprocessed_all/lacivilite001836/detections.json
# Processed folder: lacomedie13balz, results saved to preprocessed_all/lacomedie13balz/detections.json
# Processed folder: lacomedie33balz, results saved to preprocessed_all/lacomedie33balz/detections.json
# Processed folder: lacomediehum01balz, results saved to preprocessed_all/lacomediehum01balz/detections.json
# Processed folder: laforetenchantee00pere, results saved to preprocessed_all/laforetenchantee00pere/detections.json
# Processed folder: lagloire00fabr, results saved to preprocessed_all/lagloire00fabr/detections.json
# Processed folder: lajournee00pari, results saved to preprocessed_all/lajournee00pari/detections.json
# Processed folder: lamadve, results saved to preprocessed_all/lamadve/detections.json
# Processed folder: lameboyhowhelear00burdiala, results saved to preprocessed_all/lameboyhowhelear00burdiala/detections.json
# Processed folder: lamerecadichon00gaul, results saved to preprocessed_all/lamerecadichon00gaul/detections.json
# Processed folder: lamidesenfants00berq, results saved to preprocessed_all/lamidesenfants00berq/detections.json
# Processed folder: larcheden00guig, results saved to preprocessed_all/larcheden00guig/detections.json
# Processed folder: lassofdorchester00barn, results saved to preprocessed_all/lassofdorchester00barn/detections.json
# Processed folder: lastofhuggermugg00craniala, results saved to preprocessed_all/lastofhuggermugg00craniala/detections.json
# Processed folder: launchboysadvent00elli, results saved to preprocessed_all/launchboysadvent00elli/detections.json
# Processed folder: learningbetterth00careiala, results saved to preprocessed_all/learningbetterth00careiala/detections.json
# Processed folder: leavesforchristm00bostiala, results saved to preprocessed_all/leavesforchristm00bostiala/detections.json
# Processed folder: lebeauchateau00cuch, results saved to preprocessed_all/lebeauchateau00cuch/detections.json
# Processed folder: lebondieuchezles00jamm, results saved to preprocessed_all/lebondieuchezles00jamm/detections.json
# Processed folder: lebravohistoirev00coopiala, results saved to preprocessed_all/lebravohistoirev00coopiala/detections.json
# Processed folder: lecorsairerouger00coopiala, results saved to preprocessed_all/lecorsairerouger00coopiala/detections.json
# Processed folder: leftendedwards00barb, results saved to preprocessed_all/leftendedwards00barb/detections.json
# Processed folder: leftguardgilbert00barb, results saved to preprocessed_all/leftguardgilbert00barb/detections.json
# Processed folder: lefttacklethayer00barb, results saved to preprocessed_all/lefttacklethayer00barb/detections.json
# Processed folder: legendesbret00becq, results saved to preprocessed_all/legendesbret00becq/detections.json
# Processed folder: legendesvalais00sola, results saved to preprocessed_all/legendesvalais00sola/detections.json
# Processed folder: legendsofkingart00know, results saved to preprocessed_all/legendsofkingart00know/detections.json
# Processed folder: legendsofrhine00guer, results saved to preprocessed_all/legendsofrhine00guer/detections.json
# Processed folder: legeneraldouraki00comt, results saved to preprocessed_all/legeneraldouraki00comt/detections.json
# Processed folder: leisurehoursoren00wakeiala, results saved to preprocessed_all/leisurehoursoren00wakeiala/detections.json
# Processed folder: leisurehoursorev00andeiala, results saved to preprocessed_all/leisurehoursorev00andeiala/detections.json
# Processed folder: lenawingomohawks00elli, results saved to preprocessed_all/lenawingomohawks00elli/detections.json
# Processed folder: leparadistricolo00walt, results saved to preprocessed_all/leparadistricolo00walt/detections.json
# Processed folder: lepetitchaperonv00lich, results saved to preprocessed_all/lepetitchaperonv00lich/detections.json
# Processed folder: lesbonsenfants00comt, results saved to preprocessed_all/lesbonsenfants00comt/detections.json
# Processed folder: lescapadedemique00camo, results saved to preprocessed_all/lescapadedemique00camo/detections.json
# Processed folder: lescontesdeperra00perr, results saved to preprocessed_all/lescontesdeperra00perr/detections.json
# Processed folder: lesdeuxjumeauxou00manc, results saved to preprocessed_all/lesdeuxjumeauxou00manc/detections.json
# Processed folder: lesenfantsdestui00pitr, results saved to preprocessed_all/lesenfantsdestui00pitr/detections.json
# Processed folder: lesepreuves00ried, results saved to preprocessed_all/lesepreuves00ried/detections.json
# Processed folder: lesfiancees00mont, results saved to preprocessed_all/lesfiancees00mont/detections.json
# Processed folder: lesmalheursdesop00comt, results saved to preprocessed_all/lesmalheursdesop00comt/detections.json
# Processed folder: lesmotshistoriqu00trog, results saved to preprocessed_all/lesmotshistoriqu00trog/detections.json
# Processed folder: lesplusbellesfab00lafo, results saved to preprocessed_all/lesplusbellesfab00lafo/detections.json
# Processed folder: lessonsforyouths00philiala, results saved to preprocessed_all/lessonsforyouths00philiala/detections.json
# Processed folder: lessonsfromwomen00haleiala, results saved to preprocessed_all/lessonsfromwomen00haleiala/detections.json
# Processed folder: lessonsofwisdomf00fletiala, results saved to preprocessed_all/lessonsofwisdomf00fletiala/detections.json
# Processed folder: lesvacances00comt, results saved to preprocessed_all/lesvacances00comt/detections.json
# Processed folder: letitialauramora00mothiala, results saved to preprocessed_all/letitialauramora00mothiala/detections.json
# Processed folder: lettersbetweenma00johniala, results saved to preprocessed_all/lettersbetweenma00johniala/detections.json
# Processed folder: lettersfromcatpu00jack, results saved to preprocessed_all/lettersfromcatpu00jack/detections.json
# Processed folder: lettersonimprove00chapiala, results saved to preprocessed_all/lettersonimprove00chapiala/detections.json
# Processed folder: letterstoyoungge00lothiala, results saved to preprocessed_all/letterstoyoungge00lothiala/detections.json
# Processed folder: lewiscarrollinwo00mose, results saved to preprocessed_all/lewiscarrollinwo00mose/detections.json
# Processed folder: lhistoiredeladec00lameiala, results saved to preprocessed_all/lhistoiredeladec00lameiala/detections.json
# Processed folder: lifeadventuresof00delaiala, results saved to preprocessed_all/lifeadventuresof00delaiala/detections.json
# Processed folder: lifeadventuresof00dobbiala, results saved to preprocessed_all/lifeadventuresof00dobbiala/detections.json
# Processed folder: lifeadventuresof00goodiala, results saved to preprocessed_all/lifeadventuresof00goodiala/detections.json
# Processed folder: lifeadventuresof00grayiala, results saved to preprocessed_all/lifeadventuresof00grayiala/detections.json
# Processed folder: lifeadventuresof00marsiala, results saved to preprocessed_all/lifeadventuresof00marsiala/detections.json
# Processed folder: lifedeathjennywr00londiala, results saved to preprocessed_all/lifedeathjennywr00londiala/detections.json
# Processed folder: lifedeathjennywr00newyiala, results saved to preprocessed_all/lifedeathjennywr00newyiala/detections.json
# Processed folder: lifedeathjenwren00newyiala, results saved to preprocessed_all/lifedeathjenwren00newyiala/detections.json
# Processed folder: lifedeathofcockr00newyiala, results saved to preprocessed_all/lifedeathofcockr00newyiala/detections.json
# Processed folder: lifedeathofcockr00philiala, results saved to preprocessed_all/lifedeathofcockr00philiala/detections.json
# Processed folder: lifedeathofjenny00londiala, results saved to preprocessed_all/lifedeathofjenny00londiala/detections.json
